# %%
import pandas as pd
import apimoex
import requests
from datetime import date

# %%
with requests.Session() as session:
    data = apimoex.get_board_history(session, 'SBER')
    df = pd.DataFrame(data)

# %%
df
# Out:
#      BOARDID   TRADEDATE   CLOSE    VOLUME         VALUE
# 0       TQBR  2013-03-25   98.79    593680  5.934000e+07
# 1       TQBR  2013-03-26   97.20   1283550  1.260304e+08
# 2       TQBR  2013-03-27   96.75   1261950  1.218359e+08
# 3       TQBR  2013-03-28   98.59   1971410  1.924698e+08
# 4       TQBR  2013-03-29   98.76    782000  7.726886e+07
# ...      ...         ...     ...       ...           ...
# 2507    TQBR  2023-03-06  171.84  64585290  1.111158e+10
# 2508    TQBR  2023-03-07  174.01  55287380  9.555925e+09
# 2509    TQBR  2023-03-09  172.55  80393110  1.394316e+10
# 2510    TQBR  2023-03-10  172.53  50256970  8.636905e+09
# 2511    TQBR  2023-03-13  172.15  74032280  1.270953e+10
#
# [2512 rows x 5 columns]

# %%
from json import load

# %%
# load(open('moex/config.json', 'r')).get('tickers')

# %%
df = df.dropna()

# %%
df
# Out:
#      BOARDID   TRADEDATE   CLOSE    VOLUME         VALUE
# 0       TQBR  2013-03-25   98.79    593680  5.934000e+07
# 1       TQBR  2013-03-26   97.20   1283550  1.260304e+08
# 2       TQBR  2013-03-27   96.75   1261950  1.218359e+08
# 3       TQBR  2013-03-28   98.59   1971410  1.924698e+08
# 4       TQBR  2013-03-29   98.76    782000  7.726886e+07
# ...      ...         ...     ...       ...           ...
# 2507    TQBR  2023-03-06  171.84  64585290  1.111158e+10
# 2508    TQBR  2023-03-07  174.01  55287380  9.555925e+09
# 2509    TQBR  2023-03-09  172.55  80393110  1.394316e+10
# 2510    TQBR  2023-03-10  172.53  50256970  8.636905e+09
# 2511    TQBR  2023-03-13  172.15  74032280  1.270953e+10
#
# [2494 rows x 5 columns]

# %%
mask = (df['TRADEDATE'] > '2022-01-01') & (df['TRADEDATE'] <= '2022-31-01')

# %%
df.loc[mask]
# Out:
#      BOARDID   TRADEDATE   CLOSE    VOLUME         VALUE
# 2212    TQBR  2022-01-03  305.47  50183170  1.511647e+10
# 2213    TQBR  2022-01-04  304.24  53270410  1.627717e+10
# 2214    TQBR  2022-01-05  287.01  70017630  2.074094e+10
# 2215    TQBR  2022-01-06  293.92  79380930  2.312860e+10
# 2217    TQBR  2022-01-10  291.69  67426550  1.975769e+10
# ...      ...         ...     ...       ...           ...
# 2459    TQBR  2022-12-26  140.95  49379370  6.912819e+09
# 2460    TQBR  2022-12-27  139.90  41654530  5.856966e+09
# 2461    TQBR  2022-12-28  139.51  28045010  3.911971e+09
# 2462    TQBR  2022-12-29  140.96  32059860  4.513089e+09
# 2463    TQBR  2022-12-30  141.15  28175080  3.968971e+09
#
# [234 rows x 5 columns]

# %%
from moex.moex import get_historical, cut_historical

# %%
t = get_historical('SBER')

# %%
t.tail()
# Out:
#        TRADEDATE   CLOSE    VOLUME         VALUE
# 2507  2023-03-06  171.84  64585290  1.111158e+10
# 2508  2023-03-07  174.01  55287380  9.555925e+09
# 2509  2023-03-09  172.55  80393110  1.394316e+10
# 2510  2023-03-10  172.53  50256970  8.636905e+09
# 2511  2023-03-13  172.15  74032280  1.270953e+10

# %%
cut_historical(t, '2022-01-01', '2022-12-31')
# Out:
#        TRADEDATE   CLOSE    VOLUME         VALUE
# 2212  2022-01-03  305.47  50183170  1.511647e+10
# 2213  2022-01-04  304.24  53270410  1.627717e+10
# 2214  2022-01-05  287.01  70017630  2.074094e+10
# 2215  2022-01-06  293.92  79380930  2.312860e+10
# 2217  2022-01-10  291.69  67426550  1.975769e+10
# ...          ...     ...       ...           ...
# 2459  2022-12-26  140.95  49379370  6.912819e+09
# 2460  2022-12-27  139.90  41654530  5.856966e+09
# 2461  2022-12-28  139.51  28045010  3.911971e+09
# 2462  2022-12-29  140.96  32059860  4.513089e+09
# 2463  2022-12-30  141.15  28175080  3.968971e+09
#
# [234 rows x 4 columns]

# %%
from config.reader import read_config

# %%
cfg = read_config('config.json')

# %%
from postgres.postgres import connect

# %%
t
# Out:
#        TRADEDATE   CLOSE    VOLUME         VALUE
# 0     2013-03-25   98.79    593680  5.934000e+07
# 1     2013-03-26   97.20   1283550  1.260304e+08
# 2     2013-03-27   96.75   1261950  1.218359e+08
# 3     2013-03-28   98.59   1971410  1.924698e+08
# 4     2013-03-29   98.76    782000  7.726886e+07
# ...          ...     ...       ...           ...
# 2507  2023-03-06  171.84  64585290  1.111158e+10
# 2508  2023-03-07  174.01  55287380  9.555925e+09
# 2509  2023-03-09  172.55  80393110  1.394316e+10
# 2510  2023-03-10  172.53  50256970  8.636905e+09
# 2511  2023-03-13  172.15  74032280  1.270953e+10
#
# [2494 rows x 4 columns]

# %%
pd.to_datetime(['2019-01-15 00:00:00']).astype(int)
# Out:
# Int64Index([1547510400000000000], dtype='int64')

# %%
tmp = t

# %%
len(cfg.get('tickers'))
# Out:
# 63

# %%
str(list(set(cfg.get('tickers')))).replace("'", '"')
# Out:
# '["PIKK", "VKCO", "GEMC", "TATN", "CBOM", "TGKA", "GAZP", "NVTK", "MOEX", "HHRU", "ROSN", "SBER", "TCSG", "YNDX", "PHOR", "DSKY", "SFTL", "GMKN", "CIAN", "LKOH", "CHMF", "MTLRP", "LENT", "RTKMP", "RENI", "POSI", "MAGN", "OKEY", "MDMG", "ETLN", "POLY", "BSPB", "AGRO", "QIWI", "MTLR", "MVID", "GLTR", "PLZL", "SBERP", "FIXP", "SFIN", "HYDR", "FLOT", "SELG"]'

# %%
len(list(set(cfg.get('tickers'))))
# Out:
# 44

# %%
html ='''<table><thead class="ui-table__head"><tr><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Идентификатор финансового инструмента" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Код</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Краткое наименование ценной бумаги" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Кратк. наим.</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Цена последней сделки" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Последняя</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Изменение цены последней сделки к последней цене предыдущего дня, %" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Изм., %</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Цена первой сделки" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Первая</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Минимальная цена сделки" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Мин.</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Максимальная цена сделки" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Макс.</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Средневзвешенная цена" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Ср.взвеш.</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Объем совершенных сделок, в валюте расчетов" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modSorted_1wbqc UiTableBase_column_modDirection_asc_1mM3G -asc"><span>Объем</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Время последнего обновления" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Время</span></div></span></span></th></tr></thead><tbody><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=POLY"> POLY </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Polymetal </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=RUAL"> RUAL </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> РУСАЛ ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=RTKMP"> RTKMP </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Ростел -ап </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:02 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=RTKM"> RTKM </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Ростел -ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=ROSN"> ROSN </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Роснефть </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=RNFT"> RNFT </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> РуссНфт ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:02 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=RENI"> RENI </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Ренессанс </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:01 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=QIWI"> QIWI </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> iQIWI </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=POSI"> POSI </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> iПозитив </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=SBER"> SBER </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Сбербанк </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=PLZL"> PLZL </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Полюс </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=PIKK"> PIKK </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> ПИК ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=PHOR"> PHOR </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> ФосАгро ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=OZON"> OZON </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> OZON-адр </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=OKEY"> OKEY </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> OKEY-гдр </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:01 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=NVTK"> NVTK </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Новатэк ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=NLMK"> NLMK </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> НЛМК ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=MVID"> MVID </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> М.видео </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=TATNP"> TATNP </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Татнфт 3ап </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=YNDX"> YNDX </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Yandex clA </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=WUSH"> WUSH </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> iВУШХолднг </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:03 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=VTBR"> VTBR </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> ВТБ ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=VKCO"> VKCO </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> VK-гдр </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=UPRO"> UPRO </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Юнипро ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=TRNFP"> TRNFP </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Транснф ап </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr></tbody></table>'''

# %%
b = pd.read_html(html)[0]
a = b['Код'].tolist()

# %%
html = '''<table><thead class="ui-table__head"><tr><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Идентификатор финансового инструмента" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Код</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Краткое наименование ценной бумаги" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Кратк. наим.</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Цена последней сделки" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Последняя</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Изменение цены последней сделки к последней цене предыдущего дня, %" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Изм., %</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Цена первой сделки" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Первая</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Минимальная цена сделки" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Мин.</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Максимальная цена сделки" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Макс.</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Средневзвешенная цена" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Ср.взвеш.</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Объем совершенных сделок, в валюте расчетов" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modSorted_1wbqc UiTableBase_column_modDirection_asc_1mM3G -asc"><span>Объем</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Время последнего обновления" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Время</span></div></span></span></th></tr></thead><tbody><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=TGKA"> TGKA </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> ТГК-1 </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:02 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=TCSG"> TCSG </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> TCS-гдр </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=MTSS"> MTSS </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> МТС-ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=TATN"> TATN </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Татнфт 3ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=SMLT"> SMLT </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Самолет ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=SGZH"> SGZH </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Сегежа </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=SFTL"> SFTL </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> iNVTQ-гдр </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:02 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=SFIN"> SFIN </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> ЭсЭфАй ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:02 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=SELG"> SELG </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Селигдар </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:02 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=SBERP"> SBERP </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Сбербанк-п </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=CIAN"> CIAN </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> CIAN-адр </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=FLOT"> FLOT </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Совкомфлот </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=FIXP"> FIXP </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> FIXP-гдр </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=FIVE"> FIVE </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> FIVE-гдр </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=FEES"> FEES </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Россети </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=ETLN"> ETLN </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> ETLN-гдр </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:01 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=ENRU"> ENRU </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> ЭЛ5Энер ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:01 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=ENPG"> ENPG </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> ЭН+ГРУП ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=DSKY"> DSKY </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> ДетскийМир </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=GAZP"> GAZP </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> ГАЗПРОМ ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=CHMF"> CHMF </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> СевСт-ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=CBOM"> CBOM </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> МКБ ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=BSPB"> BSPB </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> БСП ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:01 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=BELU"> BELU </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Белуга ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=ALRS"> ALRS </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> АЛРОСА ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr></tbody></table>'''

# %%
b = pd.read_html(html)[0]
b_ = b['Код'].tolist()

# %%
html = '''<table><thead class="ui-table__head"><tr><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Идентификатор финансового инструмента" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Код</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Краткое наименование ценной бумаги" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Кратк. наим.</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Цена последней сделки" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Последняя</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Изменение цены последней сделки к последней цене предыдущего дня, %" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Изм., %</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Цена первой сделки" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Первая</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Минимальная цена сделки" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Мин.</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Максимальная цена сделки" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Макс.</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Средневзвешенная цена" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Ср.взвеш.</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Объем совершенных сделок, в валюте расчетов" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modSorted_1wbqc UiTableBase_column_modDirection_asc_1mM3G -asc"><span>Объем</span></div></span></span></th><th class="ui-table-col"><span class="ui-table-col__content"><span class="ui-table-col__title"><div title="Время последнего обновления" class="UiTableBase_column_modSortable_1dKK1 UiTableBase_column_modDirection_asc_1mM3G"><span>Время</span></div></span></span></th></tr></thead><tbody><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=AGRO"> AGRO </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> AGRO-гдр </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:01 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=AFLT"> AFLT </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Аэрофлот </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=LKOH"> LKOH </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> ЛУКОЙЛ </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=MTLRP"> MTLRP </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Мечел ап </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=MTLR"> MTLR </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Мечел ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=MSNG"> MSNG </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> +МосЭнерго </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:01 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=MOEX"> MOEX </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> МосБиржа </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=MGNT"> MGNT </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Магнит ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=MDMG"> MDMG </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> MDMG-гдр </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:01 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=MAGN"> MAGN </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> ММК </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=LSRG"> LSRG </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> ЛСР ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:01 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=AFKS"> AFKS </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Система ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=LENT"> LENT </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> Лента ао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:01 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=IRAO"> IRAO </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> ИнтерРАОао </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=HYDR"> HYDR </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> РусГидро </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=HHRU"> HHRU </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> iHHRU-адр </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=GMKN"> GMKN </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> ГМКНорНик </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=GLTR"> GLTR </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> GLTR-гдр </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:08 </div></td></tr><tr class="ui-table-row -interactive"><td class="ui-table-cell"><div class="SecValue_cell_1T6mS"><a href="/ru/issue.aspx?board=TQBR&amp;code=GEMC"> GEMC </a></div></td><td class="ui-table-cell"><div class="GeneralValue_cell_3uWJX"> GEMC-гдр </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div class="PercentValue_cell_2te0M"> 0&nbsp;% </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> - </div></td><td class="ui-table-cell"><div> 06:31:01 </div></td></tr></tbody></table>'''

# %%
b = pd.read_html(html)[0]
c = b['Код'].tolist()

# %%
l = ['POLY',
 'RUAL',
 'RTKMP',
 'RTKM',
 'ROSN',
 'RNFT',
 'RENI',
 'QIWI',
 'POSI',
 'SBER',
 'PLZL',
 'PIKK',
 'PHOR',
 'OZON',
 'OKEY',
 'NVTK',
 'NLMK',
 'MVID',
 'TATNP',
 'YNDX',
 'WUSH',
 'VTBR',
 'VKCO',
 'UPRO',
 'TRNFP',
 'TGKA',
 'TCSG',
 'MTSS',
 'TATN',
 'SMLT',
 'SGZH',
 'SFTL',
 'SFIN',
 'SELG',
 'SBERP',
 'CIAN',
 'FLOT',
 'FIXP',
 'FIVE',
 'FEES',
 'ETLN',
 'ENRU',
 'ENPG',
 'DSKY',
 'GAZP',
 'CHMF',
 'CBOM',
 'BSPB',
 'BELU',
 'ALRS',
 'AGRO',
 'AFLT',
 'LKOH',
 'MTLRP',
 'MTLR',
 'MSNG',
 'MOEX',
 'MGNT',
 'MDMG',
 'MAGN',
 'LSRG',
 'AFKS',
 'LENT',
 'IRAO',
 'HYDR',
 'HHRU',
 'GMKN',
 'GLTR',
 'GEMC']

# %%
len(l)
# Out:
# 69

# %%
str(l).replace("'", '"')
# Out:
# '["POLY", "RUAL", "RTKMP", "RTKM", "ROSN", "RNFT", "RENI", "QIWI", "POSI", "SBER", "PLZL", "PIKK", "PHOR", "OZON", "OKEY", "NVTK", "NLMK", "MVID", "TATNP", "YNDX", "WUSH", "VTBR", "VKCO", "UPRO", "TRNFP", "TGKA", "TCSG", "MTSS", "TATN", "SMLT", "SGZH", "SFTL", "SFIN", "SELG", "SBERP", "CIAN", "FLOT", "FIXP", "FIVE", "FEES", "ETLN", "ENRU", "ENPG", "DSKY", "GAZP", "CHMF", "CBOM", "BSPB", "BELU", "ALRS", "AGRO", "AFLT", "LKOH", "MTLRP", "MTLR", "MSNG", "MOEX", "MGNT", "MDMG", "MAGN", "LSRG", "AFKS", "LENT", "IRAO", "HYDR", "HHRU", "GMKN", "GLTR", "GEMC"]'
